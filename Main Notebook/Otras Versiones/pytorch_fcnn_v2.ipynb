# %%
# %pip install torch
# %pip install captum

# %%
# Initial imports
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

import torch.nn.functional as F
from sklearn.metrics import precision_score, recall_score, f1_score

import captum
from captum.attr import IntegratedGradients
from captum.attr import LayerConductance
from captum.attr import NeuronConductance

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy import stats
import pandas as pd

# %%
# Update path to dataset here.
dataset_path = "titanic.csv"

# %%
# Read dataset from csv file.
titanic_data = pd.read_csv(dataset_path)

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Con los datos cargados, ahora preprocesamos los datos convirtiendo algunas características categóricas como el género, la ubicación del embarque y la clase de pasajero en codificaciones únicas (columnas de características separadas para cada clase con 0/1).
# También eliminamos algunas características que son más difíciles de analizar, como el nombre, y completamos los valores faltantes en la edad y la tarifa con los valores promedio.

# %% [markdown]
# En este caso, cada categoría en cada columna se convertirá en un número entero único. Sin embargo, ten en cuenta que si hay una relación ordinal entre las categorías, como en el caso de "Pclass" (clase de pasajero), podría ser más apropiado utilizar el enfoque de variables ficticias (dummy variables) para evitar la interpretación errónea de un orden implícito.
#
# Al final, la elección entre LabelEncoder y el enfoque de variables ficticias depende del contexto y la naturaleza de tus datos. Si no hay un orden implícito entre las categorías y el modelo de aprendizaje automático que utilizarás puede manejar variables categóricas codificadas de manera ordinal, LabelEncoder puede ser una opción adecuada. Sin embargo, si las categorías no tienen un orden natural o el orden puede introducir sesgos, es preferible utilizar el enfoque de variables ficticias.

# %%
titanic_data = pd.concat([titanic_data,
                          pd.get_dummies(titanic_data['Sex'], dtype=int),
                          pd.get_dummies(titanic_data['Embarked'],prefix="Embark", dtype=int),
                          pd.get_dummies(titanic_data['Pclass'],prefix="Class", dtype=int)], axis=1)

titanic_data["Age"] = titanic_data["Age"].fillna(titanic_data["Age"].mean())
titanic_data["Fare"] = titanic_data["Fare"].fillna(titanic_data["Fare"].mean())

titanic_data = titanic_data.drop(['PassengerId', 'Name','Ticket','Sex','Embarked','Pclass', 'Cabin'], axis=1)

# %%
titanic_data.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  female  male  Embark_C  Embark_Q
# 0         0  22.0      1      0   7.2500       0     1         0         0  \
# 1         1  38.0      1      0  71.2833       1     0         1         0
# 2         1  26.0      0      0   7.9250       1     0         0         0
# 3         1  35.0      1      0  53.1000       1     0         0         0
# 4         0  35.0      0      0   8.0500       0     1         0         0
#
#    Embark_S  Class_1  Class_2  Class_3
# 0         1        0        0        1
# 1         0        1        0        0
# 2         1        0        0        1
# 3         1        1        0        0
# 4         1        0        0        1

# %%
# Guardamos el DataFrame en un archivo CSV
titanic_data.to_csv('titanic_data.csv')

# %% [markdown]
# Después del procesamiento, las características que tenemos son:
#
# Age  - Edad del Pasajero
# Sibsp - Número de hermanos/cónyuges a bordo
# Parch - Número de padres/hijos a bordo
# Fare  - Importe de tarifa pagado en libras esterlinas
# Female  - Variable binaria que indica si el pasajero es mujer
# Male  - Variable binaria que indica si el pasajero es hombre
# EmbarkC - Variable binaria que indica si el pasajero se embarcó en Cherburgo
# EmbarkQ: variable binaria que indica si el pasajero se embarcó en Queenstown
# EmbarkS - Variable binaria que indica si el pasajero se embarcó en Southampton
# Class1 - Variable binaria que indica si el pasajero estaba en primera clase
# Class2 - Variable binaria que indica si el pasajero estaba en segunda clase
# Class3 - Variable binaria que indica si el pasajero estaba en tercera clase

# %% [markdown]
# Ahora convertimos los datos en matrices numpy y separamos los conjuntos de entrenamiento y prueba.

# %%
#Split data into training features and labels
X, y = titanic_data.loc[:, titanic_data.columns != 'Survived'], titanic_data['Survived']

from sklearn.model_selection import train_test_split
# split data into train and test sets
seed = 42
test_size = 0.4
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

# %% [markdown]
# Ahora estamos listos para definir la arquitectura de la red neuronal que usaremos para la tarea.  Hemos definido una arquitectura simple utilizando 2 capas ocultas, la primera con 12 unidades ocultas y la segunda con 8 unidades ocultas, cada una con no linealidad sigmoide.  La capa final realiza una operación softmax y tiene 2 unidades, correspondientes a las salidas de sobrevivido (1) o no sobrevivido (0).

# %%
class TitanicSimpleNNModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(12, 64)
        self.relu1 = nn.ReLU()
        self.linear2 = nn.Linear(64, 32)
        self.relu2 = nn.ReLU()
        self.linear3 = nn.Linear(32, 16)
        self.relu3 = nn.ReLU()
        self.linear4 = nn.Linear(16, 2)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        lin1_out = self.linear1(x)
        relu_out1 = self.relu1(lin1_out)
        relu_out2 = self.relu2(self.linear2(relu_out1))
        relu_out3 = self.relu3(self.linear3(relu_out2))
        return self.softmax(self.linear4(relu_out3))
    
    def predict(self, x):
        if isinstance(x, np.ndarray):
            x = torch.from_numpy(x).float()
        elif isinstance(x, torch.Tensor):
            x = x.float()
            
        x = x.view(x.size(0), -1)
        output = self.forward(x)
        predicted_probs = torch.softmax(output, dim=1)
        return predicted_probs


    
    def predict_lime(self, x):
        if isinstance(x, np.ndarray):
            x = torch.from_numpy(x).float()
        elif isinstance(x, torch.Tensor):
            x = x.float()

        x = x.view(x.size(0), -1)
        output = self.forward(x)
        predicted_probs = torch.softmax(output, dim=1)
        _, predicted_labels = torch.max(predicted_probs, 1)
        return predicted_probs.detach().numpy()
    
# Declaramos una nueva instancia de clase
net = TitanicSimpleNNModel()

# %% [markdown]
# Podemos usar un modelo previamente entrenado o entrenar la red usando los datos de entrenamiento para 200 épocas. Tenga en cuenta que los resultados de los pasos posteriores pueden no coincidir si se vuelve a entrenar.

# %%
net = TitanicSimpleNNModel()
USE_PRETRAINED_MODEL = False

USE_PRETRAINED_MODEL = False


def calculate_metrics(predictions, targets):
    predicted_labels = torch.argmax(predictions, dim=1)
    accuracy = (predicted_labels == targets).sum().item() / len(targets)
    precision = precision_score(targets, predicted_labels)
    recall = recall_score(targets, predicted_labels)
    f1 = f1_score(targets, predicted_labels)
    return accuracy, precision, recall, f1

if USE_PRETRAINED_MODEL:
    net.load_state_dict(torch.load('titanic_model.pt'))
    print("Model Loaded!")

    X_train_t = torch.from_numpy((X_train.to_numpy()).astype(float)).type(torch.FloatTensor)
    y_train_t = torch.from_numpy(y_train.to_numpy())
    X_test_t = torch.from_numpy((X_test.to_numpy()).astype(float)).type(torch.FloatTensor)
    y_test_t = torch.from_numpy(y_test.to_numpy())
else:
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(net.parameters(), lr=0.001)

    X_train_t = torch.from_numpy((X_train.to_numpy()).astype(float)).type(torch.FloatTensor)
    y_train_t = torch.from_numpy(y_train.to_numpy())
    X_test_t = torch.from_numpy((X_test.to_numpy()).astype(float)).type(torch.FloatTensor)
    y_test_t = torch.from_numpy(y_test.to_numpy())

    

    # Listas para almacenar los valores de loss y accuracy en cada epoch
    train_loss_values = []
    train_accuracy_values = []
    test_loss_values = []
    test_accuracy_values = []

    # Entrenamiento del modelo
    num_epochs = 200
    batch_size = 32

    for epoch in range(num_epochs):
        running_loss = 0.0

        # Crear un DataLoader para iterar sobre los mini-batches de entrenamiento
        train_dataset = TensorDataset(X_train_t, y_train_t)
        train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

        for inputs, targets in train_dataloader:
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        # Calcular las métricas en el conjunto de entrenamiento
        train_predictions = net.predict(X_train_t)
        train_accuracy, _, _, _ = calculate_metrics(train_predictions, y_train_t)

        # Calcular las métricas en el conjunto de prueba
        test_predictions = net.predict(X_test_t)
        test_accuracy, _, _, _ = calculate_metrics(test_predictions, y_test_t)

        # Almacenar los valores de loss y accuracy en cada epoch
        train_loss_values.append(running_loss)
        train_accuracy_values.append(train_accuracy)
        test_loss_values.append(loss.item())
        test_accuracy_values.append(test_accuracy)

        # Imprimir las métricas en cada epoch
        print(f"Epoch {epoch+1} - Train Loss: {running_loss:.4f} - Train Accuracy: {train_accuracy:.4f} - Test Accuracy: {test_accuracy:.4f}")

    # Graficar los valores de loss y accuracy
    epochs = range(1, num_epochs+1)

    plt.figure(figsize=(12, 4))

    # Gráfico de loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_loss_values, label='Train')
    plt.plot(epochs, test_loss_values, label='Test')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Test Loss')
    plt.legend()

    # Gráfico de accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracy_values, label='Train')
    plt.plot(epochs, test_accuracy_values, label='Test')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and Test Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Realizar la validación cruzada
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from skorch import NeuralNetClassifier

# Crear una instancia de NeuralNetClassifier
net_classifier = NeuralNetClassifier(
    net,
    criterion=nn.CrossEntropyLoss(),
    optimizer=torch.optim.Adam,
    lr=0.001,
    max_epochs=10,
    batch_size=32
)

# Crear una instancia de KFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

# Realizar la validación cruzada y calcular la precisión
scores = cross_val_score(net_classifier, X_train_t, y_train, cv=cv, scoring='accuracy')

# Imprimir los resultados de cada fold
print("Scores de validación cruzada:", scores)

# Imprimir el promedio y la desviación estándar de los scores
print("Promedio de scores:", scores.mean())
print("Desviación estándar de scores:", scores.std())
# Out:
# Epoch 1 - Train Loss: 10.9715 - Train Accuracy: 0.6536 - Test Accuracy: 0.6695
# Epoch 2 - Train Loss: 10.5973 - Train Accuracy: 0.6685 - Test Accuracy: 0.6863
# Epoch 3 - Train Loss: 10.4767 - Train Accuracy: 0.6629 - Test Accuracy: 0.6863
# Epoch 4 - Train Loss: 10.4818 - Train Accuracy: 0.6723 - Test Accuracy: 0.6807
# Epoch 5 - Train Loss: 10.3598 - Train Accuracy: 0.6966 - Test Accuracy: 0.7031
# Epoch 6 - Train Loss: 10.4854 - Train Accuracy: 0.6873 - Test Accuracy: 0.7003
# Epoch 7 - Train Loss: 10.4052 - Train Accuracy: 0.6779 - Test Accuracy: 0.7087
# Epoch 8 - Train Loss: 10.2744 - Train Accuracy: 0.7060 - Test Accuracy: 0.7031
# Epoch 9 - Train Loss: 10.1959 - Train Accuracy: 0.7135 - Test Accuracy: 0.7171
# Epoch 10 - Train Loss: 10.1517 - Train Accuracy: 0.7154 - Test Accuracy: 0.7227
# Epoch 11 - Train Loss: 10.0532 - Train Accuracy: 0.7154 - Test Accuracy: 0.7311
# Epoch 12 - Train Loss: 9.9235 - Train Accuracy: 0.7247 - Test Accuracy: 0.7451
# Epoch 13 - Train Loss: 9.7948 - Train Accuracy: 0.7341 - Test Accuracy: 0.7255
# Epoch 14 - Train Loss: 9.7118 - Train Accuracy: 0.7472 - Test Accuracy: 0.7703
# Epoch 15 - Train Loss: 9.5058 - Train Accuracy: 0.7640 - Test Accuracy: 0.7647
# Epoch 16 - Train Loss: 9.2676 - Train Accuracy: 0.7603 - Test Accuracy: 0.7591
# Epoch 17 - Train Loss: 9.1045 - Train Accuracy: 0.8109 - Test Accuracy: 0.7759
# Epoch 18 - Train Loss: 8.8350 - Train Accuracy: 0.8090 - Test Accuracy: 0.7759
# Epoch 19 - Train Loss: 8.7250 - Train Accuracy: 0.8221 - Test Accuracy: 0.8011
# Epoch 20 - Train Loss: 8.6595 - Train Accuracy: 0.8240 - Test Accuracy: 0.8011
# Epoch 21 - Train Loss: 8.4824 - Train Accuracy: 0.8390 - Test Accuracy: 0.8011
# Epoch 22 - Train Loss: 8.3569 - Train Accuracy: 0.7734 - Test Accuracy: 0.7619
# Epoch 23 - Train Loss: 8.5054 - Train Accuracy: 0.8202 - Test Accuracy: 0.7787
# Epoch 24 - Train Loss: 8.3889 - Train Accuracy: 0.8277 - Test Accuracy: 0.7927
# Epoch 25 - Train Loss: 8.4771 - Train Accuracy: 0.8146 - Test Accuracy: 0.7787
# Epoch 26 - Train Loss: 8.3472 - Train Accuracy: 0.8333 - Test Accuracy: 0.8039
# Epoch 27 - Train Loss: 8.1694 - Train Accuracy: 0.8371 - Test Accuracy: 0.7899
# Epoch 28 - Train Loss: 8.3220 - Train Accuracy: 0.8184 - Test Accuracy: 0.7759
# Epoch 29 - Train Loss: 8.1335 - Train Accuracy: 0.8408 - Test Accuracy: 0.7955
# Epoch 30 - Train Loss: 8.2067 - Train Accuracy: 0.8240 - Test Accuracy: 0.7843
# Epoch 31 - Train Loss: 8.1505 - Train Accuracy: 0.8240 - Test Accuracy: 0.7787
# Epoch 32 - Train Loss: 8.2237 - Train Accuracy: 0.8202 - Test Accuracy: 0.7843
# Epoch 33 - Train Loss: 8.1383 - Train Accuracy: 0.8277 - Test Accuracy: 0.7955
# Epoch 34 - Train Loss: 8.0982 - Train Accuracy: 0.8464 - Test Accuracy: 0.7983
# Epoch 35 - Train Loss: 8.1831 - Train Accuracy: 0.8296 - Test Accuracy: 0.8039
# Epoch 36 - Train Loss: 8.0671 - Train Accuracy: 0.8483 - Test Accuracy: 0.7927
# Epoch 37 - Train Loss: 7.9849 - Train Accuracy: 0.8446 - Test Accuracy: 0.7927
# Epoch 38 - Train Loss: 8.0644 - Train Accuracy: 0.8427 - Test Accuracy: 0.7955
# Epoch 39 - Train Loss: 8.0238 - Train Accuracy: 0.8184 - Test Accuracy: 0.7703
# Epoch 40 - Train Loss: 8.0762 - Train Accuracy: 0.8390 - Test Accuracy: 0.7983
# Epoch 41 - Train Loss: 7.9884 - Train Accuracy: 0.8464 - Test Accuracy: 0.7843
# Epoch 42 - Train Loss: 8.0174 - Train Accuracy: 0.8390 - Test Accuracy: 0.7983
# Epoch 43 - Train Loss: 8.0092 - Train Accuracy: 0.8352 - Test Accuracy: 0.7955
# Epoch 44 - Train Loss: 8.3760 - Train Accuracy: 0.8090 - Test Accuracy: 0.7703
# Epoch 45 - Train Loss: 8.2153 - Train Accuracy: 0.8427 - Test Accuracy: 0.7927
# Epoch 46 - Train Loss: 8.0078 - Train Accuracy: 0.8483 - Test Accuracy: 0.7927
# Epoch 47 - Train Loss: 8.0488 - Train Accuracy: 0.8427 - Test Accuracy: 0.7983
# Epoch 48 - Train Loss: 7.8537 - Train Accuracy: 0.8296 - Test Accuracy: 0.7899
# Epoch 49 - Train Loss: 8.2032 - Train Accuracy: 0.8464 - Test Accuracy: 0.7955
# Epoch 50 - Train Loss: 7.9877 - Train Accuracy: 0.8390 - Test Accuracy: 0.8095
# Epoch 51 - Train Loss: 7.9573 - Train Accuracy: 0.8333 - Test Accuracy: 0.7983
# Epoch 52 - Train Loss: 8.1001 - Train Accuracy: 0.8352 - Test Accuracy: 0.7983
# Epoch 53 - Train Loss: 7.9500 - Train Accuracy: 0.8464 - Test Accuracy: 0.7983
# Epoch 54 - Train Loss: 7.8877 - Train Accuracy: 0.8483 - Test Accuracy: 0.8039
# Epoch 55 - Train Loss: 7.9158 - Train Accuracy: 0.8521 - Test Accuracy: 0.7983
# Epoch 56 - Train Loss: 7.8380 - Train Accuracy: 0.8371 - Test Accuracy: 0.7955
# Epoch 57 - Train Loss: 8.1546 - Train Accuracy: 0.8446 - Test Accuracy: 0.8039
# Epoch 58 - Train Loss: 8.0222 - Train Accuracy: 0.8427 - Test Accuracy: 0.7955
# Epoch 59 - Train Loss: 7.9039 - Train Accuracy: 0.8315 - Test Accuracy: 0.7815
# Epoch 60 - Train Loss: 7.9690 - Train Accuracy: 0.8258 - Test Accuracy: 0.7815
# Epoch 61 - Train Loss: 8.2083 - Train Accuracy: 0.8408 - Test Accuracy: 0.8011
# Epoch 62 - Train Loss: 8.0111 - Train Accuracy: 0.8464 - Test Accuracy: 0.7983
# Epoch 63 - Train Loss: 7.8122 - Train Accuracy: 0.8427 - Test Accuracy: 0.7955
# Epoch 64 - Train Loss: 8.0150 - Train Accuracy: 0.8109 - Test Accuracy: 0.7675
# Epoch 65 - Train Loss: 7.9560 - Train Accuracy: 0.8483 - Test Accuracy: 0.8011
# Epoch 66 - Train Loss: 7.9895 - Train Accuracy: 0.8408 - Test Accuracy: 0.7927
# Epoch 67 - Train Loss: 7.9915 - Train Accuracy: 0.7940 - Test Accuracy: 0.7451
# Epoch 68 - Train Loss: 8.2163 - Train Accuracy: 0.8352 - Test Accuracy: 0.7955
# Epoch 69 - Train Loss: 7.8272 - Train Accuracy: 0.8502 - Test Accuracy: 0.8067
# Epoch 70 - Train Loss: 7.7940 - Train Accuracy: 0.8502 - Test Accuracy: 0.8039
# Epoch 71 - Train Loss: 7.8375 - Train Accuracy: 0.8408 - Test Accuracy: 0.7899
# Epoch 72 - Train Loss: 7.7737 - Train Accuracy: 0.8521 - Test Accuracy: 0.8039
# Epoch 73 - Train Loss: 7.8200 - Train Accuracy: 0.8483 - Test Accuracy: 0.8095
# Epoch 74 - Train Loss: 7.9577 - Train Accuracy: 0.8408 - Test Accuracy: 0.7955
# Epoch 75 - Train Loss: 7.9728 - Train Accuracy: 0.8390 - Test Accuracy: 0.7815
# Epoch 76 - Train Loss: 7.9027 - Train Accuracy: 0.8296 - Test Accuracy: 0.7787
# Epoch 77 - Train Loss: 7.8462 - Train Accuracy: 0.8539 - Test Accuracy: 0.8067
# Epoch 78 - Train Loss: 7.8314 - Train Accuracy: 0.8464 - Test Accuracy: 0.8067
# Epoch 79 - Train Loss: 7.8337 - Train Accuracy: 0.8464 - Test Accuracy: 0.7983
# Epoch 80 - Train Loss: 7.7801 - Train Accuracy: 0.8521 - Test Accuracy: 0.8067
# Epoch 81 - Train Loss: 7.8151 - Train Accuracy: 0.8539 - Test Accuracy: 0.8011
# Epoch 82 - Train Loss: 7.8234 - Train Accuracy: 0.8521 - Test Accuracy: 0.8067
# Epoch 83 - Train Loss: 7.8837 - Train Accuracy: 0.8596 - Test Accuracy: 0.7983
# Epoch 84 - Train Loss: 7.8007 - Train Accuracy: 0.8352 - Test Accuracy: 0.7815
# Epoch 85 - Train Loss: 8.0501 - Train Accuracy: 0.8464 - Test Accuracy: 0.8123
# Epoch 86 - Train Loss: 7.7616 - Train Accuracy: 0.8502 - Test Accuracy: 0.7927
# Epoch 87 - Train Loss: 7.8818 - Train Accuracy: 0.8596 - Test Accuracy: 0.7983
# Epoch 88 - Train Loss: 7.8514 - Train Accuracy: 0.8464 - Test Accuracy: 0.8067
# Epoch 89 - Train Loss: 7.8316 - Train Accuracy: 0.8596 - Test Accuracy: 0.8011
# Epoch 90 - Train Loss: 8.0880 - Train Accuracy: 0.8371 - Test Accuracy: 0.7703
# Epoch 91 - Train Loss: 7.9806 - Train Accuracy: 0.8558 - Test Accuracy: 0.8011
# Epoch 92 - Train Loss: 7.8541 - Train Accuracy: 0.8521 - Test Accuracy: 0.8123
# Epoch 93 - Train Loss: 7.7597 - Train Accuracy: 0.8558 - Test Accuracy: 0.8095
# Epoch 94 - Train Loss: 7.8077 - Train Accuracy: 0.8614 - Test Accuracy: 0.7927
# Epoch 95 - Train Loss: 7.7327 - Train Accuracy: 0.8633 - Test Accuracy: 0.8011
# Epoch 96 - Train Loss: 7.7515 - Train Accuracy: 0.8502 - Test Accuracy: 0.7955
# Epoch 97 - Train Loss: 7.7626 - Train Accuracy: 0.8577 - Test Accuracy: 0.7983
# Epoch 98 - Train Loss: 7.7088 - Train Accuracy: 0.8596 - Test Accuracy: 0.8039
# Epoch 99 - Train Loss: 7.7224 - Train Accuracy: 0.8539 - Test Accuracy: 0.7927
# Epoch 100 - Train Loss: 7.7641 - Train Accuracy: 0.8577 - Test Accuracy: 0.7983
# Epoch 101 - Train Loss: 7.6960 - Train Accuracy: 0.8614 - Test Accuracy: 0.7983
# Epoch 102 - Train Loss: 7.6619 - Train Accuracy: 0.8483 - Test Accuracy: 0.7843
# Epoch 103 - Train Loss: 7.9854 - Train Accuracy: 0.8221 - Test Accuracy: 0.7731
# Epoch 104 - Train Loss: 7.9036 - Train Accuracy: 0.8464 - Test Accuracy: 0.8067
# Epoch 105 - Train Loss: 7.9890 - Train Accuracy: 0.8502 - Test Accuracy: 0.7955
# Epoch 106 - Train Loss: 7.7676 - Train Accuracy: 0.8614 - Test Accuracy: 0.8039
# Epoch 107 - Train Loss: 7.7480 - Train Accuracy: 0.8521 - Test Accuracy: 0.8095
# Epoch 108 - Train Loss: 7.7899 - Train Accuracy: 0.8577 - Test Accuracy: 0.7955
# Epoch 109 - Train Loss: 7.8155 - Train Accuracy: 0.8446 - Test Accuracy: 0.8011
# Epoch 110 - Train Loss: 7.7516 - Train Accuracy: 0.8614 - Test Accuracy: 0.7927
# Epoch 111 - Train Loss: 7.7267 - Train Accuracy: 0.8652 - Test Accuracy: 0.7899
# Epoch 112 - Train Loss: 7.8125 - Train Accuracy: 0.8558 - Test Accuracy: 0.7955
# Epoch 113 - Train Loss: 7.6261 - Train Accuracy: 0.8446 - Test Accuracy: 0.7955
# Epoch 114 - Train Loss: 7.8363 - Train Accuracy: 0.8577 - Test Accuracy: 0.8011
# Epoch 115 - Train Loss: 7.7239 - Train Accuracy: 0.8670 - Test Accuracy: 0.7983
# Epoch 116 - Train Loss: 7.8267 - Train Accuracy: 0.8614 - Test Accuracy: 0.8011
# Epoch 117 - Train Loss: 7.7765 - Train Accuracy: 0.8577 - Test Accuracy: 0.7899
# Epoch 118 - Train Loss: 7.8000 - Train Accuracy: 0.8558 - Test Accuracy: 0.7843
# Epoch 119 - Train Loss: 7.7452 - Train Accuracy: 0.8539 - Test Accuracy: 0.8095
# Epoch 120 - Train Loss: 7.6440 - Train Accuracy: 0.8427 - Test Accuracy: 0.7983
# Epoch 121 - Train Loss: 7.7680 - Train Accuracy: 0.8652 - Test Accuracy: 0.7955
# Epoch 122 - Train Loss: 7.8114 - Train Accuracy: 0.8670 - Test Accuracy: 0.8039
# Epoch 123 - Train Loss: 7.8445 - Train Accuracy: 0.8558 - Test Accuracy: 0.8095
# Epoch 124 - Train Loss: 7.9042 - Train Accuracy: 0.8371 - Test Accuracy: 0.7955
# Epoch 125 - Train Loss: 7.8290 - Train Accuracy: 0.8558 - Test Accuracy: 0.7927
# Epoch 126 - Train Loss: 7.7272 - Train Accuracy: 0.8633 - Test Accuracy: 0.7927
# Epoch 127 - Train Loss: 7.7848 - Train Accuracy: 0.8539 - Test Accuracy: 0.8039
# Epoch 128 - Train Loss: 7.7485 - Train Accuracy: 0.8464 - Test Accuracy: 0.7815
# Epoch 129 - Train Loss: 7.7908 - Train Accuracy: 0.8502 - Test Accuracy: 0.7871
# Epoch 130 - Train Loss: 7.9803 - Train Accuracy: 0.8483 - Test Accuracy: 0.8011
# Epoch 131 - Train Loss: 7.6729 - Train Accuracy: 0.8689 - Test Accuracy: 0.8011
# Epoch 132 - Train Loss: 7.6165 - Train Accuracy: 0.8596 - Test Accuracy: 0.8095
# Epoch 133 - Train Loss: 7.6911 - Train Accuracy: 0.8558 - Test Accuracy: 0.7871
# Epoch 134 - Train Loss: 7.7579 - Train Accuracy: 0.8652 - Test Accuracy: 0.8095
# Epoch 135 - Train Loss: 7.6926 - Train Accuracy: 0.8614 - Test Accuracy: 0.8095
# Epoch 136 - Train Loss: 7.6606 - Train Accuracy: 0.8502 - Test Accuracy: 0.7843
# Epoch 137 - Train Loss: 7.8169 - Train Accuracy: 0.8614 - Test Accuracy: 0.8011
# Epoch 138 - Train Loss: 7.6060 - Train Accuracy: 0.8633 - Test Accuracy: 0.7927
# Epoch 139 - Train Loss: 7.7212 - Train Accuracy: 0.8371 - Test Accuracy: 0.8067
# Epoch 140 - Train Loss: 7.7003 - Train Accuracy: 0.8652 - Test Accuracy: 0.8011
# Epoch 141 - Train Loss: 7.5923 - Train Accuracy: 0.8633 - Test Accuracy: 0.8067
# Epoch 142 - Train Loss: 7.6944 - Train Accuracy: 0.8521 - Test Accuracy: 0.7983
# Epoch 143 - Train Loss: 7.7894 - Train Accuracy: 0.8502 - Test Accuracy: 0.8067
# Epoch 144 - Train Loss: 7.6881 - Train Accuracy: 0.8670 - Test Accuracy: 0.8039
# Epoch 145 - Train Loss: 7.6677 - Train Accuracy: 0.8464 - Test Accuracy: 0.7787
# Epoch 146 - Train Loss: 7.8215 - Train Accuracy: 0.8577 - Test Accuracy: 0.8039
# Epoch 147 - Train Loss: 7.7130 - Train Accuracy: 0.8577 - Test Accuracy: 0.7955
# Epoch 148 - Train Loss: 7.7347 - Train Accuracy: 0.8614 - Test Accuracy: 0.7927
# Epoch 149 - Train Loss: 7.6899 - Train Accuracy: 0.8670 - Test Accuracy: 0.7955
# Epoch 150 - Train Loss: 7.5919 - Train Accuracy: 0.8614 - Test Accuracy: 0.7927
# Epoch 151 - Train Loss: 7.6589 - Train Accuracy: 0.8558 - Test Accuracy: 0.7899
# Epoch 152 - Train Loss: 7.6995 - Train Accuracy: 0.8689 - Test Accuracy: 0.7983
# Epoch 153 - Train Loss: 7.6648 - Train Accuracy: 0.8652 - Test Accuracy: 0.8067
# Epoch 154 - Train Loss: 7.6649 - Train Accuracy: 0.8652 - Test Accuracy: 0.8011
# Epoch 155 - Train Loss: 7.7453 - Train Accuracy: 0.8596 - Test Accuracy: 0.8011
# Epoch 156 - Train Loss: 7.6190 - Train Accuracy: 0.8596 - Test Accuracy: 0.7983
# Epoch 157 - Train Loss: 7.7491 - Train Accuracy: 0.8502 - Test Accuracy: 0.7759
# Epoch 158 - Train Loss: 7.7467 - Train Accuracy: 0.8577 - Test Accuracy: 0.7955
# Epoch 159 - Train Loss: 7.6664 - Train Accuracy: 0.8670 - Test Accuracy: 0.8011
# Epoch 160 - Train Loss: 7.6878 - Train Accuracy: 0.8614 - Test Accuracy: 0.7899
# Epoch 161 - Train Loss: 7.6210 - Train Accuracy: 0.8521 - Test Accuracy: 0.7871
# Epoch 162 - Train Loss: 7.6823 - Train Accuracy: 0.8521 - Test Accuracy: 0.7927
# Epoch 163 - Train Loss: 7.7281 - Train Accuracy: 0.8652 - Test Accuracy: 0.8039
# Epoch 164 - Train Loss: 7.6570 - Train Accuracy: 0.8708 - Test Accuracy: 0.7983
# Epoch 165 - Train Loss: 7.5782 - Train Accuracy: 0.8633 - Test Accuracy: 0.7871
# Epoch 166 - Train Loss: 7.6795 - Train Accuracy: 0.8689 - Test Accuracy: 0.7927
# Epoch 167 - Train Loss: 7.5952 - Train Accuracy: 0.8670 - Test Accuracy: 0.8067
# Epoch 168 - Train Loss: 7.6187 - Train Accuracy: 0.8689 - Test Accuracy: 0.8039
# Epoch 169 - Train Loss: 7.6325 - Train Accuracy: 0.8670 - Test Accuracy: 0.8039
# Epoch 170 - Train Loss: 7.6084 - Train Accuracy: 0.8708 - Test Accuracy: 0.8011
# Epoch 171 - Train Loss: 7.6244 - Train Accuracy: 0.8577 - Test Accuracy: 0.8067
# Epoch 172 - Train Loss: 7.6839 - Train Accuracy: 0.8577 - Test Accuracy: 0.7899
# Epoch 173 - Train Loss: 7.6189 - Train Accuracy: 0.8652 - Test Accuracy: 0.8039
# Epoch 174 - Train Loss: 7.5972 - Train Accuracy: 0.8708 - Test Accuracy: 0.8067
# Epoch 175 - Train Loss: 7.8661 - Train Accuracy: 0.8652 - Test Accuracy: 0.7899
# Epoch 176 - Train Loss: 7.5533 - Train Accuracy: 0.8708 - Test Accuracy: 0.7983
# Epoch 177 - Train Loss: 7.6687 - Train Accuracy: 0.8614 - Test Accuracy: 0.8039
# Epoch 178 - Train Loss: 7.5889 - Train Accuracy: 0.8689 - Test Accuracy: 0.8011
# Epoch 179 - Train Loss: 7.5964 - Train Accuracy: 0.8633 - Test Accuracy: 0.8067
# Epoch 180 - Train Loss: 7.6417 - Train Accuracy: 0.8539 - Test Accuracy: 0.7983
# Epoch 181 - Train Loss: 7.5992 - Train Accuracy: 0.8652 - Test Accuracy: 0.7843
# Epoch 182 - Train Loss: 8.2329 - Train Accuracy: 0.8371 - Test Accuracy: 0.7647
# Epoch 183 - Train Loss: 8.1442 - Train Accuracy: 0.8390 - Test Accuracy: 0.7899
# Epoch 184 - Train Loss: 7.7144 - Train Accuracy: 0.8464 - Test Accuracy: 0.7955
# Epoch 185 - Train Loss: 7.7308 - Train Accuracy: 0.8577 - Test Accuracy: 0.8039
# Epoch 186 - Train Loss: 7.7618 - Train Accuracy: 0.8558 - Test Accuracy: 0.7955
# Epoch 187 - Train Loss: 7.6426 - Train Accuracy: 0.8521 - Test Accuracy: 0.8067
# Epoch 188 - Train Loss: 7.6723 - Train Accuracy: 0.8502 - Test Accuracy: 0.7731
# Epoch 189 - Train Loss: 7.8737 - Train Accuracy: 0.8596 - Test Accuracy: 0.7927
# Epoch 190 - Train Loss: 7.7512 - Train Accuracy: 0.8577 - Test Accuracy: 0.8039
# Epoch 191 - Train Loss: 7.7356 - Train Accuracy: 0.8652 - Test Accuracy: 0.7871
# Epoch 192 - Train Loss: 7.6348 - Train Accuracy: 0.8670 - Test Accuracy: 0.7927
# Epoch 193 - Train Loss: 7.5620 - Train Accuracy: 0.8727 - Test Accuracy: 0.7983
# Epoch 194 - Train Loss: 7.5747 - Train Accuracy: 0.8745 - Test Accuracy: 0.7927
# Epoch 195 - Train Loss: 7.5085 - Train Accuracy: 0.8727 - Test Accuracy: 0.7983
# Epoch 196 - Train Loss: 7.6252 - Train Accuracy: 0.8521 - Test Accuracy: 0.7787
# Epoch 197 - Train Loss: 7.5755 - Train Accuracy: 0.8670 - Test Accuracy: 0.8011
# Epoch 198 - Train Loss: 7.6653 - Train Accuracy: 0.8614 - Test Accuracy: 0.7871
# Epoch 199 - Train Loss: 7.8655 - Train Accuracy: 0.8521 - Test Accuracy: 0.7983
# Epoch 200 - Train Loss: 7.8226 - Train Accuracy: 0.8558 - Test Accuracy: 0.7843
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4729       0.8721        0.4444  0.0661
#       2        0.4621       0.8721        0.4342  0.1549
#       3        0.4517       0.8605        0.4541  0.1398
#       4        0.4643       0.8721        0.4427  0.1014
#       5        0.4499       0.8721        0.4431  0.1050
#       6        0.4600       0.8837        0.4306  0.1038
#       7        0.4505       0.8721        0.4451  0.1138
#       8        0.4506       0.8721        0.4388  0.1029
#       9        0.4507       0.8721        0.4450  0.1106
#      10        0.4584       0.8721        0.4425  0.1187
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4652       0.8953        0.4137  0.1376
#       2        0.4517       0.8837        0.4333  0.1243
#       3        0.4622       0.8953        0.4151  0.1208
#       4        0.4519       0.8953        0.4134  0.1287
#       5        0.4481       0.8953        0.4152  0.1204
#       6        0.4538       0.8953        0.4296  0.1236
#       7        0.4541       0.8953        0.4185  0.1337
#       8        0.4496       0.8953        0.4158  0.1129
#       9        0.4532       0.8953        0.4175  0.1204
#      10        0.4537       0.8953        0.4129  0.1066
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4687       0.9302        0.3820  0.1118
#       2        0.4626       0.9186        0.3899  0.1006
#       3        0.4629       0.9186        0.3852  0.1181
#       4        0.4586       0.9186        0.3898  0.1080
#       5        0.4611       0.9186        0.3910  0.1159
#       6        0.4591       0.9186        0.3892  0.1012
#       7        0.4593       0.9302        0.3834  0.2102
#       8        0.4587       0.9186        0.3941  0.1170
#       9        0.4603       0.9302        0.3842  0.1179
#      10        0.4571       0.9186        0.3900  0.1239
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4661       0.8953        0.4139  0.0919
#       2        0.4446       0.8953        0.4282  0.1023
#       3        0.4660       0.8953        0.4191  0.1021
#       4        0.4506       0.9070        0.4030  0.0884
#       5        0.4421       0.8953        0.4236  0.0886
#       6        0.4426       0.8953        0.4094  0.0941
#       7        0.4420       0.8953        0.4223  0.1055
#       8        0.4454       0.8953        0.4125  0.0914
#       9        0.4467       0.8953        0.4257  0.0946
#      10        0.4408       0.8953        0.4122  0.1110
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4637       0.8721        0.4410  0.0952
#       2        0.4527       0.8721        0.4299  0.0956
#       3        0.4551       0.8953        0.4218  0.0941
#       4        0.4491       0.8721        0.4564  0.0881
#       5        0.4560       0.8721        0.4414  0.2020
#       6        0.4566       0.8721        0.4343  0.1317
#       7        0.4504       0.8721        0.4405  0.1012
#       8        0.4514       0.8721        0.4326  0.0953
#       9        0.4495       0.8721        0.4319  0.0960
#      10        0.4502       0.8721        0.4338  0.1000
# Scores de validación cruzada: [0.88785047 0.8411215  0.85046729 0.8411215  0.85849057]
# Promedio de scores: 0.8558102627402574
# Desviación estándar de scores: 0.017284824964532052

# %% [markdown]
# Para evitar el overfitting en nuestro modelo se ha implementado un sistemas de mini_batches y se ha realizado un cross validation en nuestro modelo.

# %% [markdown]
# Ahora podemos evaluar las precisiones de entrenamiento y prueba de nuestro modelo.

# %% [markdown]
# * Probamos el método "predict_lime" de la clase "TitanicSimpleNNModel"

# %%
single_input = X_test_t[0].unsqueeze(0)
predict = net.predict_lime(single_input)
print( 'Prediction: ',predict, 'Input size: ', single_input.shape)
# Out:
# Prediction:  [[0.7309989  0.26900113]] Input size:  torch.Size([1, 12])

# %%
multiple_input = X_test_t[:10]
predict = net.predict_lime(multiple_input)
print( 'Prediction: ',predict, 'Input size: ', multiple_input.shape)
# Out:
# Prediction:  [[0.7309989  0.26900113]
#  [0.73100275 0.26899725]
#  [0.73093086 0.26906914]
#  [0.26894343 0.7310566 ]
#  [0.5344988  0.46550122]
#  [0.26894143 0.7310586 ]
#  [0.26951802 0.730482  ]
#  [0.7294806  0.27051932]
#  [0.2745038  0.72549623]
#  [0.26941875 0.7305812 ]] Input size:  torch.Size([10, 12])

# %%
single_input = X_test_t[0].unsqueeze(0)
predict = net.predict(single_input)
print( 'Prediction: ',predict, 'Input size: ', single_input.shape)
# Out:
# Prediction:  tensor([[0.7310, 0.2690]], grad_fn=<SoftmaxBackward0>) Input size:  torch.Size([1, 12])

# %%
input = X_test_t[:10]
predict = net.predict(input)
print( 'Prediction: ',predict, 'Input size: ', input.shape)
# Out:
# Prediction:  tensor([[0.7310, 0.2690],
#         [0.7310, 0.2690],
#         [0.7309, 0.2691],
#         [0.2689, 0.7311],
#         [0.5345, 0.4655],
#         [0.2689, 0.7311],
#         [0.2695, 0.7305],
#         [0.7295, 0.2705],
#         [0.2745, 0.7255],
#         [0.2694, 0.7306]], grad_fn=<SoftmaxBackward0>) Input size:  torch.Size([10, 12])

# %% [markdown]
# Visualizamos el modelo que vamos a almacenar en un archivo para poder utilizarlo sin tener que recrear todo el proceso en otro archivo

# %%
torch.save(net.state_dict(), 'titanic_fcnn.pt')

# Cargar los pesos del modelo desde el archivo
net.load_state_dict(torch.load('titanic_fcnn.pt'))

# Asegurarse de que el modelo esté en modo de evaluación (si corresponde)
net.eval()
# Out:
# TitanicSimpleNNModel(
#   (linear1): Linear(in_features=12, out_features=64, bias=True)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=64, out_features=32, bias=True)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=32, out_features=16, bias=True)
#   (relu3): ReLU()
#   (linear4): Linear(in_features=16, out_features=2, bias=True)
#   (softmax): Softmax(dim=1)
# )
